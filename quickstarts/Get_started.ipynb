# %% [markdown]
# <a href="https://colab.research.google.com/github/akverma0023/Python-t/blob/main/quickstarts/Get_started.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Enter the number:"))
i= 1
while i<11:
  print(num, '*', i, '=', num*i)
  i += 1
# Out:
# Enter the number:105
# 105 * 1 = 105
# 105 * 2 = 210
# 105 * 3 = 315
# 105 * 4 = 420
# 105 * 5 = 525
# 105 * 6 = 630
# 105 * 7 = 735
# 105 * 8 = 840
# 105 * 9 = 945
# 105 * 10 = 1050
